# %% [markdown]
# <table>
#   <tr>
#     <td style="text-align: center;">
#       <img src="./images/pandas.png" alt="Pandas Logo"  style="margin-bottom: 80px;"/><br>
#       <a href="https://pandas.pydata.org/docs/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Pandas</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/seaborn.svg" alt="Seaborn Logo"  style="margin-bottom: 80px;" /><br>
#       <a href="https://seaborn.pydata.org/api.html" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Seaborn</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/Plotly-logo.png" alt="Plotly Logo"  style="margin-bottom: 80px;" /><br>
#       <a href="https://plotly.com/python-api-reference/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Plotly</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/altair-logo-light.png" alt="Altair Logo" style="margin-bottom: 50px;"/><br>
#       <a href="https://altair-viz.github.io/documentation/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Altair</a>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Introduction to Bar Plots
# Bar plots are a fundamental visualization tool used to display categorical data with rectangular bars. The length of each bar is proportional to the value it represents. Bar plots are excellent for comparing quantities across different categories.
#
# **When to Use Bar Plots:**
#
# - Comparing categorical data.
# - Showing the frequency or count of different categories.
# - Visualizing trends over categories.
#
# **Basic Terminology:**
#
# - Bars: The rectangular columns representing data values.
# - Axes: The horizontal (x-axis) and vertical (y-axis) lines that define the plot.
# - Labels: Text that describes the categories and values.
# - Title: The overall description of the plot.

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# ## step 1: Download the data :
# The datasets used here can be found in https://github.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/tree/master/datasets.
#
# documentation on pandas can be found here: https://pandas.pydata.org/docs/
# seaborn documentation can be found here: https://seaborn.pydata.org/

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# ## Step 2: Import needed libraries

# %%
# import pandas libraries and visualization library seeborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import altair as alt

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# ## Step 3  Describing data with pandas :

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# La bibliothèque pandas est un outil open source extrêmement puissant pour gérer, manipuler et analyser des données structurées. Les tableaux de données peuvent être stockés dans l'objet DataFrame disponible dans pandas, et des données dans divers formats (par exemple, .csv, .tsv, .xlsx, et .json) peuvent être lues directement dans un DataFrame. En utilisant des fonctions intégrées, les DataFrames peuvent être manipulés efficacement (par exemple, convertir des tableaux entre différentes vues, comme longues/larges ; regrouper par une colonne/caractéristique spécifique ; résumer les données ; et plus encore).

# %%
# you can either read the data directly from github or you can download it and 
# include its path, the dataset is also available in seaborn which means 
# you can read it via: diamonds_df = sns.load_dataset('diamonds')

#URL of the dataset: Download the dataset 
#diamonds_url = "./diamonds.csv"
#diamonds_df = pd.read_csv(diamonds_url)
#diamonds_df

diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"
diamonds_df = pd.read_csv(diamonds_url)
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### 3.1 Observing and Describing Data

# %% [markdown]
# Pour observer et décrire les données d'un dataset en utilisant pandas , une méthode très utile est la fonction head(). Cette fonction permet d'afficher les premières lignes du DataFrame, ce qui est pratique pour avoir un aperçu rapide des données. Par défaut, elle affiche 5 lignes. Pour ajuster cela, nous pouvons utiliser l'argument n ; par exemple, head(n=5). Voici quelques points clés à retenir :

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# <font color="#008000">  **Create a basic bar plot**

# %%
cut_counts = diamonds_df['cut'].value_counts()
plt.bar(cut_counts.index, cut_counts.values)

# Create a basic bar plot
plt.figure(figsize=(8, 6))
plt.bar(cut_counts.index, cut_counts.values)

#Add labels and title
plt.xlabel('Cut')
plt.ylabel('Count')
plt.title('Diamond Count by Cut')

# Show the plot
plt.show()

# %% [markdown]
# <font color="#008000">  **Comptez le nombre de lignes et de colonnes dans le DataFrame en utilisant la fonction**

# %%
# Create a customized bar plot
plt.figure(figsize=(8, 6))
plt.bar(cut_counts.index, cut_counts.values, color=['red', 'orange', 'yellow', 'green', 'blue'])  # Custom colors
plt.xlabel('Cut', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Diamond Count by Cut', fontsize=14)
plt.xticks(rotation=45)
# add a grid 
plt.grid(axis='y', linestyle='--', alpha=0.7)



# Rotate x-axis labels

# %% [markdown]
# <font color="#008000">  **Bar Plots with Seaborn**
#
# Seaborn is a library for making statistical graphics in Python. It is built on top of Matplotlib and provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# <font color="#008000">   **Create a bar plot using seaborn**

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=cut_counts.index, y=cut_counts.values)
plt.xlabel('Cut')
plt.ylabel('Count')
plt.title('Diamond Count by Cut')
plt.show()

# %% [markdown]
# <font color="#008000">  **Create a customized bar plot using seaborn**

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='cut', y='price', data=diamonds_df, palette='viridis')  # Using the 'price' column
plt.xlabel('Cut', fontsize=12)
plt.ylabel('Average Price', fontsize=12)
plt.title('Average Diamond Price by Cut', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exercise 2:**
#
# Create a bar plot using Seaborn to compare the average price for each color. Use a different color palette and customize the plot.

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='color', y='price', data=diamonds_df, palette='magma')
plt.xlabel('Color', fontsize=12)
plt.ylabel('Average Price', fontsize=12)
plt.title('Average Diamond Price by Color', fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <font color="#008000">  **Interactive Bar Plots with Plotly**
#
#
# Now take the first 100 samples of the dataframe and plot it via ploty.
# nb: if you try to plot all the values with plotly or altair, you will either get a

# %%
# Create a customized interactive bar plot

df = diamonds_df.head(1080)
fig = px.bar(df, x='cut', y='price', color='cut',
             title='Diamond Price by Cut',
             labels={'cut': 'Cut', 'price': 'Price'},
             color_discrete_sequence=px.colors.sequential.Viridis)  # Custom colors
fig.update_layout(xaxis_title_font_size=12, yaxis_title_font_size=12, showlegend=False) # Hide legend
fig.show()

# %% [markdown]
# <hr style="border: 2px solid black;">

# %%
# Exercise 4 solution
chart = alt.Chart(df).mark_bar().encode(
    x=alt.X('color', sort='-y', title='Color'),
    y=alt.Y('count()', title='Count'),
    color='color',
    tooltip=['color', 'count()']
).properties(
    title='Diamond Count by Color'
).interactive()
chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# In this tutorial, we covered how to create and customize bar plots using Matplotlib, Seaborn, Plotly, and Altair. Bar plots are a powerful tool for visualizing categorical data and comparing quantities across different categories.
#
# **Key Points:**
#
# - Matplotlib provides basic bar plot functionality with extensive customization options.
# - Seaborn offers a higher-level interface with attractive default styles and color palettes.
# - Plotly creates interactive bar plots with tooltips, zoom, and pan capabilities.
# - Altair uses a declarative syntax for creating concise and elegant bar plots.
#
# **Best Practices:**
#
# - Use clear and descriptive labels for axes and titles.
# - Choose appropriate color palettes for your data.
# - Sort categorical data for better readability.
# - Add interactivity to explore data in more detail.
#
# **Additional Resources:**
#
# - Matplotlib: [https://matplotlib.org/](https://matplotlib.org/)
# - Seaborn: [https://seaborn.pydata.org/](https://seaborn.pydata.org/)
# - Plotly: [https://plotly.com/python/](https://plotly.com/python/)
# - Altair: [https://altair-viz.github.io/](https://altair-viz.github.io/)
